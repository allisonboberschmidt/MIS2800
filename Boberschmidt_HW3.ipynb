# %% [markdown]
# <a href="https://colab.research.google.com/github/allisonboberschmidt/MIS2800/blob/main/Boberschmidt_HW3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Instruction
#
# The Below cells have errors preventing them from running
# correctly. Some have typos and some have missing text
# altogether. While AI can do many things for us - the ability to
# debug and troubleshoot is one of the most valuable skills you
# can learn.
# This document is provided to you as a PDF file. Your
# assignment is to run the code as shown successfully and
# answer the questions at the end of the document.
# The code to run the installations and imports are provided for
# you. Just be sure you type exactly as shown. Typos can be in
# the form of extra space or no space or not putting on
# separate lines.
# To Complete for Credit
# 1. Fix the errors in the 10 blocks that have an error. A brief comment has been added
# to each one to provide guidance on what is missing.
# 2. Answer the questions at the end on how you fixed the errors.
# 3. Save file into GitHub and submit the GitHub link into ISMS.
# keyboard_arrow_down Instructions
# The next six blocks provide the exact code to run to get your Colab file
# started to run SQLite3.

# %%
# Type this code exactly as shown to install the first library needed for !pip install --upgrade pandas ipython-sql prettytable==3.10.1

# %%
# Install the SQL extension. Remember to type exactly as shown here.
# !pip install ipython-sql
print("ipython sql installed")
# Out:
# ...
# ipython sql installed

# %%
# Load the SQL magic extension
# %load_ext sql

# %%
#this code imports sqlite3 and prints a statement stating it has been imort sqlite3
print("sqlite3 imported")
# Out:
# sqlite3 imported

# %%
import sqlite3
# This creates a brand-new, empty database file named 'AdCampaigns2026.d
conn = sqlite3.connect('AdCampaigns2026.db')
print("database created")
# Out:
# database created

# %%
# This line is required so Colab stops acting like Python and acts more
# %sql sqlite:///AdCampaigns2026.db

# %% [markdown]
# There are bugs (mistakes) for you to find and fix in the next 10 blocks

# %%
# %%sql
# CREATE TABLE Marketing_Brands (
#   brand_id INTEGER PRIMARY KEY,
#   brand_name TEXT,
#   brand_type TEXT,
#   brand_budget INTEGER
# ) STRICT;
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# []

# %%
# %%sql
# INSERT INTO Marketing_Brands (brand_id, brand_name, brand_type, brand_budget)
# VALUES
#   (1, 'Doritos', 'Snacks', 7000000),
#   (2, 'AWS', 'Technology', 152000000),
#   (3, 'Pepsi', 'Beverages', 2000000),
#   (4, 'He_Gets_Us', 'Religious', 1000000),
#   (5, 'Dr_Pepper', 'Beverages', 5000000),
#   (6, 'IBM', 'Technology', 100000),
#   (7, 'Google', 'Technology', 8000000);
# Out:
#  * sqlite:///AdCampaigns2026.db
# 7 rows affected.
# []

# %%
# %%sql
# SELECT * FROM Marketing_Brands;
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [(1, 'Doritos', 'Snacks', 7000000),
#  (2, 'AWS', 'Technology', 152000000),
#  (3, 'Pepsi', 'Beverages', 2000000),
#  (4, 'He_Gets_Us', 'Religious', 1000000),
#  (5, 'Dr_Pepper', 'Beverages', 5000000),
#  (6, 'IBM', 'Technology', 100000),
#  (7, 'Google', 'Technology', 8000000)]

# %%
# %%sql
# -- Instructions: Fix the code to display only the brand names and brand
# SELECT brand_name, brand_type FROM Marketing_Brands;
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [('Doritos', 'Snacks'),
#  ('AWS', 'Technology'),
#  ('Pepsi', 'Beverages'),
#  ('He_Gets_Us', 'Religious'),
#  ('Dr_Pepper', 'Beverages'),
#  ('IBM', 'Technology'),
#  ('Google', 'Technology')]

# %%
# %%sql
# -- Instructions: Fix the code to find the brand types that are Religious
# SELECT brand_type FROM Marketing_Brands WHERE brand_type = 'Religious';
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [('Religious',)]

# %%
#Block 6

# %%sql
-- Instructions: Fix the code to display the brand names that have a bud

SELECT brand_name FROM Marketing_Brands WHERE brand_budget > 7000000
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [('AWS',), ('Google',)]

# %%
# %%sql
# -- Block 7
#
# -- Instructions: Fix the code so that this will run SQLite3 in Colab witho
#
# SELECT * FROM Marketing_Brands WHERE brand_budget > 7000000
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [(2, 'AWS', 'Technology', 152000000), (7, 'Google', 'Technology', 8000000)]

# %%
#Block 8

# %%sql
-- Instructions: Find the brands where the brand is Snacks or Beverages
SELECT * FROM Marketing_Brands WHERE brand_type = 'Snacks' OR brand_type = 'Beverages';
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [(1, 'Doritos', 'Snacks', 7000000),
#  (3, 'Pepsi', 'Beverages', 2000000),
#  (5, 'Dr_Pepper', 'Beverages', 5000000)]

# %%
#Block 9

# %%sql
-- Instructions: Sort the table by brand budget in DESC order. Display o
SELECT * FROM Marketing_Brands ORDER BY brand_budget DESC;
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [(2, 'AWS', 'Technology', 152000000),
#  (7, 'Google', 'Technology', 8000000),
#  (1, 'Doritos', 'Snacks', 7000000),
#  (5, 'Dr_Pepper', 'Beverages', 5000000),
#  (3, 'Pepsi', 'Beverages', 2000000),
#  (4, 'He_Gets_Us', 'Religious', 1000000),
#  (6, 'IBM', 'Technology', 100000)]

# %%
#Block 10

#Using SQLite3 (and all its magic) to create a table showing all the co

# %% [markdown]
# Answer the Questions Below Based on the SQL Code
# You've Run Above
#
# 1. How did you fix the error in Block #1? Answer: added keyword TABLE after CREATE.
# 2. How did you fix the error in Block #2? Answer: I added the INTO Marketing_Brands keyword to specify where data should be inserted.
# 3. How did you fix the error in Block #3? Answer: I added * after SELECT to correct the statement.
# 4. How did you fix the error in Block #4? Answer: I changed the query from jsut SELECT to SELECT brand_type FROM Marketing_Brands;
# 5. How did you fix the error in Block #5? Answer: I changed it to use a WHERE clause: I changed it to SELECT brand_type FROM Marketing_Brands WHERE brand_type = 'Religious';
# 6. How did you fix the error in Block #6? Answer: I modified the SELECT * statement to SELECT brand_name.
# 7. How did you fix the error in Block #7? Answer: It was missing %%sql so I added that in. There was also a syntax error because the comments were using Python's # symbol instead of SQL's -- for single line comments.
# 8. How did you fix the error in Block #8? Answer: the original query SELECT * FROM Marketing_Brands was incomplete so I changed it to SELECT * FROM Marketing_Brands WHERE brand_type = 'Snacks' OR brand_type = 'Beverages';
# 9. How did you fix the error in Block #9? Answer: the initial SELECT statement was incomplete. I fixed it by completing the SELECT statement to SELECT * FROM Marketing_Brands ORDER BY brand_budget DESC;
# 10. How did you fix the error in Block #10? Answer: I couldn't fix this one. This is because the sentence was incomplete and made no sense.
